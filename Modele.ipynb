# %%
rm(list = ls())
library(lattice)
library(ggplot2)

# %%
df1 <- read.table('mycsv.csv')

# %%
Kp<-c(0.        , 2.29999995, 1.29999995, 2.29999995, 1.        ,
       2.        , 3.29999995, 3.29999995, 2.70000005, 0.69999999,
       0.69999999, 1.29999995, 1.        , 1.        , 1.        ,
       3.        , 0.30000001, 0.        , 0.30000001, 0.30000001,
       3.        , 0.30000001, 1.        , 2.70000005, 3.29999995,
       1.70000005, 3.        , 4.        , 4.30000019, 3.        ,
       0.30000001, 2.29999995, 2.70000005, 5.30000019, 2.70000005,
       1.29999995, 2.        , 1.        , 1.29999995, 0.30000001,
       0.30000001, 2.70000005, 0.30000001, 3.        , 4.30000019,
       2.        , 3.70000005, 5.30000019, 4.        , 2.70000005,
       2.        , 0.69999999, 4.30000019, 5.        , 4.69999981,
       2.70000005, 3.        , 2.70000005, 1.        , 2.70000005,
       3.70000005, 3.70000005, 4.30000019, 0.        , 1.        ,
       3.70000005, 0.69999999, 2.29999995, 5.30000019, 3.        ,
       3.        , 0.30000001, 4.69999981, 3.        , 5.69999981,
       1.29999995, 5.        , 1.70000005, 4.30000019, 2.70000005,
       1.70000005, 0.30000001, 4.        , 2.29999995, 4.        ,
       3.        , 5.        , 3.29999995, 4.        , 4.        ,
       3.29999995, 3.29999995, 1.29999995, 2.29999995, 4.69999981,
       1.        , 4.        , 4.        , 4.        , 4.        ,
       4.69999981, 3.70000005, 5.        , 2.29999995, 4.30000019,
       4.69999981, 5.30000019, 4.        , 1.29999995, 1.29999995,
       4.30000019, 1.29999995, 5.69999981, 5.        , 3.        ,
       4.        , 4.69999981, 5.        , 5.30000019, 5.30000019,
       5.30000019, 5.69999981, 4.        , 4.30000019, 5.        ,
       5.69999981, 4.        , 1.29999995, 4.30000019, 2.29999995,
       0.30000001, 0.69999999, 1.        , 5.69999981, 2.70000005,
       3.        , 4.69999981, 5.30000019, 3.        , 1.        ,
       5.30000019, 5.30000019, 2.70000005, 1.        , 4.        ,
       4.        , 0.30000001, 2.70000005, 4.30000019, 2.        ,
       2.29999995, 3.        , 0.30000001, 5.        , 5.        ,
       5.30000019, 2.70000005, 1.70000005, 1.        , 0.30000001,
       0.69999999, 0.30000001, 5.30000019, 5.30000019, 4.69999981,
       4.69999981, 0.        , 0.        , 4.        , 6.        ,
       4.   )

# %%
velo=c(369., 394., 411., 385., 352., 378., 352., 359., 448., 411., 374.,
       318., 371., 353., 340., 358., 431., 433., 356., 350., 703., 384.,
       323., 447., 409., 344., 586., 450., 493., 491., 422., 396., 388.,
       352., 531., 385., 390., 335., 423., 358., 352., 384., 436., 422.,
       431., 443., 474., 621., 544., 379., 351., 356., 425., 413., 423.,
       405., 495., 540., 308., 479., 368., 524., 458., 387., 457., 484.,
       444., 390., 691., 576., 501., 406., 608., 673., 757., 454., 588.,
       579., 460., 416., 391., 395., 495., 606., 539., 449., 511., 474.,
       472., 540., 422., 393., 434., 500., 653., 407., 456., 496., 475.,
       672., 702., 512., 552., 438., 508., 527., 641., 616., 558., 545.,
       597., 646., 592., 628., 398., 479., 605., 740., 720., 815., 734.,
       695., 481., 473., 463., 467., 552., 553., 536., 605., 473., 461.,
       457., 499., 471., 489., 581., 542., 514., 313., 778., 779., 672.,
       450., 724., 662., 440., 437., 562., 443., 473., 673., 352., 638.,
       751., 708., 311., 371., 389., 382., 372., 381., 581., 594., 809.,
       770., 585., 586., 516., 656., 642.)

# %%
dens<-c( 3.29999995, 13.10000038,  9.80000019,  8.69999981,  4.0999999 ,
        3.20000005, 11.19999981, 12.10000038,  7.80000019,  3.70000005,
        6.4000001 ,  6.80000019,  2.9000001 ,  6.0999999 ,  6.69999981,
        4.9000001 ,  3.4000001 ,  3.70000005,  0.69999999,  5.69999981,
        1.70000005,  4.4000001 ,  6.        ,  9.30000019, 12.19999981,
        8.10000038,  8.19999981,  2.20000005,  9.19999981,  5.30000019,
        6.5999999 ,  6.0999999 , 10.89999962,  6.9000001 ,  1.20000005,
        3.0999999 , 10.69999981,  7.4000001 ,  7.80000019,  3.20000005,
        5.19999981,  9.39999962,  3.5       ,  9.80000019,  7.5       ,
        6.30000019,  1.5       ,  2.5       , 12.10000038, 10.80000019,
       13.80000019,  9.89999962,  8.10000038,  7.9000001 ,  6.30000019,
        4.        ,  2.4000001 ,  2.5       , 14.19999981, 10.30000019,
        9.5       ,  2.0999999 ,  6.        ,  3.5999999 ,  4.5999999 ,
        7.80000019,  6.80000019,  9.80000019,  4.0999999 ,  4.5999999 ,
        5.0999999 ,  5.0999999 ,  3.0999999 ,  1.5       ,  2.5999999 ,
       12.19999981,  6.80000019,  1.89999998,  6.69999981,  6.5999999 ,
        8.69999981,  7.0999999 ,  9.60000038,  3.9000001 ,  8.39999962,
       12.39999962,  6.5       ,  4.30000019,  5.69999981,  5.5999999 ,
        6.30000019,  8.60000038,  6.30000019,  9.10000038,  1.29999995,
        6.5       ,  4.5999999 ,  5.5       ,  6.        ,  4.19999981,
        4.0999999 ,  5.30000019,  3.0999999 ,  6.80000019,  3.5       ,
        7.4000001 ,  4.5       ,  3.79999995,  3.29999995,  3.4000001 ,
        8.19999981,  1.39999998,  4.5999999 ,  4.0999999 , 10.69999981,
        4.9000001 ,  5.69999981,  7.4000001 ,  4.4000001 ,  3.        ,
        3.20000005,  2.70000005,  7.19999981,  4.4000001 ,  5.        ,
        5.4000001 , 10.19999981,  4.        ,  4.30000019,  1.29999995,
        1.        ,  1.20000005,  0.80000001,  6.9000001 ,  6.69999981,
        8.30000019,  5.30000019,  7.69999981,  5.9000001 , 14.10000038,
        4.        ,  2.20000005,  2.0999999 ,  6.80000019,  3.9000001 ,
        2.5       ,  9.10000038,  8.19999981, 10.69999981,  6.69999981,
        7.30000019,  2.79999995,  6.        ,  6.        ,  2.0999999 ,
        2.0999999 ,  5.5       ,  6.69999981,  1.29999995,  1.39999998,
        2.0999999 ,  1.79999995,  4.19999981,  4.80000019,  4.86000013,
        1.60000002,  4.4000001 ,  4.30000019, 10.10000038,  3.5999999 ,
        3.5999999)

# %%
Bz<-c( 4.5       , -3.5       ,  1.10000002, -2.        , -2.        ,
       -3.        , -4.80000019, -7.        ,  1.        ,  0.5       ,
        5.80000019, -4.        ,  7.9000001 ,  1.39999998, -0.69999999,
       -6.4000001 ,  3.5       ,  3.5       ,  5.69999981,  2.79999995,
        4.69999981,  3.9000001 , -0.60000002,  5.30000019, -1.        ,
       -4.4000001 ,  2.        , -4.69999981,  1.10000002, -0.5       ,
        4.30000019, -4.19999981,  2.0999999 ,  0.        ,  1.10000002,
        0.89999998,  3.9000001 , -0.89999998, -1.        ,  2.5       ,
        3.29999995, -4.0999999 ,  1.10000002,  0.60000002,  1.70000005,
        4.0999999 , -4.80000019, -4.        ,  5.4000001 ,  2.70000005,
        1.70000005,  4.5       , -7.5       , -7.5       , -4.        ,
       -3.5999999 , -2.79999995,  3.4000001 ,  6.5       ,  5.19999981,
       -4.4000001 , -1.79999995, -1.5       ,  3.0999999 ,  4.19999981,
        3.4000001 ,  0.80000001,  0.5       ,  0.40000001, -2.4000001 ,
       -1.        ,  0.30000001,  2.5       ,  0.89999998, -4.9000001 ,
        6.        , -0.69999999, -1.39999998,  0.30000001, -5.        ,
       -3.        ,  5.0999999 ,  2.79999995,  2.70000005, -3.        ,
        2.79999995, -4.5999999 , -3.4000001 , -3.0999999 , -5.9000001 ,
       -2.9000001 , -2.29999995,  4.19999981,  2.79999995, -5.        ,
        0.89999998, -3.4000001 , -6.5       , -1.5       ,  3.        ,
        3.79999995, -5.5       , -3.5999999 , -1.20000005, -5.        ,
       -3.0999999 , -3.20000005,  0.2       ,  0.60000002,  0.1       ,
       -3.5999999 ,  4.69999981, -5.5       , -2.79999995, -2.5999999 ,
       -4.0999999 , -3.        , -3.70000005, -0.60000002, -2.29999995,
       -5.4000001 , -2.5       , -5.80000019, -2.        , -5.80000019,
       -5.69999981, -3.20000005,  4.5999999 , -6.        ,  5.80000019,
        0.89999998, -1.79999995,  2.5       , -2.20000005, -0.2       ,
        4.0999999 , -2.29999995, -0.40000001,  1.70000005,  5.69999981,
       -7.5       , -0.80000001,  2.5       ,  4.9000001 ,  2.0999999 ,
        0.5       ,  5.80000019,  2.79999995,  2.5999999 ,  3.20000005,
        4.69999981,  2.0999999 ,  1.20000005, -0.2       , -1.39999998,
       -2.70000005, -2.79999995,  4.4000001 ,  1.10000002, -0.2       ,
       -2.5999999 ,  1.5       , -5.9000001 , -2.79999995, -0.5       ,
       -1.89999998,  3.9000001 ,  4.        , -0.80000001, -3.79999995,
        1.79999995)

# %%
table <- data.frame(kp=Kp,v=velo,n=dens,bz=Bz,v2=velo**2,n2=dens**2,bz2=Bz**2,ebz=exp(Bz),sn=sinh(dens),sbz=sinh(Bz))
#,tn=tanh(dens),tn=tanh(Bz)
kp=Kp;v=velo;n=dens;bz=Bz;v2=velo**2;n2=dens**2;
bz2=Bz**2;ebz=exp(Bz);sn=sinh(dens);sbz=sinh(Bz)

# %%
summary(lm(kp ~ .^3, data = table))
# Out:
# Call:
# lm(formula = kp ~ .^3, data = table)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.6944 -0.1679  0.0000  0.1060  2.3394
#
# Coefficients: (2 not defined because of singularities)
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -1.004e+03  2.042e+03  -0.492  0.62547
# v            4.159e+00  5.238e+00   0.794  0.43162
# n           -1.150e+02  1.781e+02  -0.646  0.52192
# bz          -1.344e+03  1.819e+03  -0.739  0.46405
# v2          -3.262e-03  5.540e-03  -0.589  0.55904
# n2           1.159e+01  3.075e+01   0.377  0.70822
# bz2         -2.800e+02  3.392e+02  -0.825  0.41371
# ebz          1.074e+03  2.044e+03   0.525  0.60195
# sn           1.441e-01  3.381e+00   0.043  0.96620
# sbz          7.381e+02  8.316e+02   0.888  0.37972
# v:n          1.164e-01  5.998e-01   0.194  0.84705
# v:bz         6.437e+00  4.910e+00   1.311  0.19688
# v:v2        -3.160e-07  1.088e-06  -0.290  0.77296
# v:n2        -2.757e-02  1.202e-01  -0.229  0.81962
# ...

# %%
summary(lm(kp ~ebz:sn+v:n:bz2+v:bz:v2+v:v2:bz2+v:v2:sbz+v:n2:bz2+n:v2:bz2+bz:bz2:sbz, data = table))
# Out:
# Call:
# lm(formula = kp ~ ebz:sn + v:n:bz2 + v:bz:v2 + v:v2:bz2 + v:v2:sbz +
#     v:n2:bz2 + n:v2:bz2 + bz:bz2:sbz, data = table)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -2.36286 -1.21381  0.09381  0.95728  3.09510
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  2.645e+00  1.618e-01  16.351  < 2e-16 ***
# ebz:sn      -2.124e-09  3.912e-09  -0.543   0.5879
# v:n:bz2     -4.095e-05  1.798e-05  -2.277   0.0241 *
# v:bz:v2     -1.599e-09  2.292e-10  -6.975 7.38e-11 ***
# v:bz2:v2     2.659e-11  1.098e-10   0.242   0.8089
# v:v2:sbz     1.671e-11  5.319e-12   3.141   0.0020 **
# v:bz2:n2     7.932e-07  1.021e-06   0.776   0.4386
# n:bz2:v2     8.108e-08  3.608e-08   2.247   0.0260 *
# bz2:bz:sbz   3.310e-07  1.983e-06   0.167   0.8676
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 1.423 on 162 degrees of freedom
# Multiple R-squared:   0.34,	Adjusted R-squared:  0.3074
# ...

# %%
table1 <- data.frame(kp=Kp,v=velo,n=dens,bz=Bz,v2=velo**2,n2=dens**2,bz2=Bz**2,ebz=exp(Bz))
#,tn=tanh(dens),tn=tanh(Bz)
summary(lm(kp ~ .^4, data = table1))
# Out:
# Call:
# lm(formula = kp ~ .^4, data = table1)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.7907 -0.2142 -0.0010  0.2075  3.2867
#
# Coefficients:
#                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)    1.617e+03  7.352e+02   2.199   0.0311 *
# v             -8.791e+00  4.182e+00  -2.102   0.0391 *
# n             -3.310e+02  1.658e+02  -1.996   0.0497 *
# bz             1.114e+03  4.640e+02   2.401   0.0189 *
# v2             1.404e-02  7.215e-03   1.946   0.0555 .
# n2             4.001e+01  2.294e+01   1.744   0.0854 .
# bz2            2.590e+02  1.156e+02   2.241   0.0281 *
# ebz           -1.278e+03  7.188e+02  -1.778   0.0797 .
# v:n            1.878e+00  7.781e-01   2.413   0.0184 *
# v:bz          -6.071e+00  2.611e+00  -2.325   0.0229 *
# v:v2          -6.635e-06  3.923e-06  -1.691   0.0951 .
# v:n2          -2.383e-01  1.242e-01  -1.919   0.0589 .
# v:bz2         -1.439e+00  6.335e-01  -2.271   0.0261 *
# ...

# %%
table2 <- data.frame(kp=Kp,v=velo,n=dens,bz=Bz,v2=velo**2,v12=velo**(1/2),n2=dens**(1/2),bz2=Bz**(2/3),ebz=exp(Bz))
#,tn=tanh(dens),tn=tanh(Bz)
summary(lm(kp ~ .^2, data = table2))
# Out:
# Call:
# lm(formula = kp ~ .^2, data = table2)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.51499 -0.42308  0.00231  0.36235  1.86083
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -1.795e+05  1.120e+05  -1.603   0.1159
# v           -5.500e+03  3.465e+03  -1.587   0.1193
# n            6.089e+02  3.035e+02   2.006   0.0508 .
# bz          -6.659e+02  8.965e+02  -0.743   0.4614
# v2          -1.094e+01  7.036e+00  -1.555   0.1268
# v12          4.887e+04  3.058e+04   1.598   0.1169
# n2          -2.987e+03  1.304e+03  -2.291   0.0266 *
# bz2          1.126e+03  1.639e+03   0.687   0.4956
# ebz          3.513e+00  4.814e+00   0.730   0.4692
# v:n          2.547e+00  1.309e+00   1.946   0.0578 .
# v:bz        -2.954e+00  3.850e+00  -0.767   0.4467
# v:v2        -1.427e-03  9.404e-04  -1.517   0.1360
# v:v12        3.280e+02  2.085e+02   1.573   0.1226
# v:n2        -1.237e+01  5.467e+00  -2.263   0.0284 *
# ...

# %%
table3 <- data.frame(kp=Kp,v=velo,n=dens,bz=Bz,v2=velo**2,vlog=log(v),n2=dens**(1/2),bz2=Bz**(2/3),ebz=exp(Bz))
#,tn=tanh(dens),tn=tanh(Bz)
summary(lm(kp ~ .^3, data = table3))
# Out:
# Call:
# lm(formula = kp ~ .^3, data = table3)
#
# Residuals:
#          1          3          9         10         11         13         14
#  6.663e-03  5.699e-02  5.437e-01  1.040e-01 -8.189e-03  3.210e-05 -2.958e-01
#         17         18         19         20         21         22         24
#  3.465e-01 -3.031e-01  1.242e-03  6.080e-02 -2.869e-03 -3.091e-01  1.809e-05
#         27         29         31         33         34         35         36
#  3.512e-03 -6.665e-02 -2.813e-01 -1.639e-01 -5.583e-03  3.274e-02 -6.513e-04
#         37         40         41         43         44         45         46
#  1.489e-02  2.690e-03 -3.506e-02  8.267e-04 -1.519e-01  4.058e-01  5.055e-01
#         49         50         51         52         58         59         60
#  1.535e-03  2.063e-01 -9.717e-03 -9.223e-02 -2.736e-02 -3.053e-04  5.366e-02
#         64         65         66         67         68         69         72
# ...

# %%
table5 <- data.frame(kp=Kp,v=velo,n=dens,bz=Bz,v2=velo**2,n2=dens**2,bz2=Bz**2,ev=exp(Bz))
#,tn=tanh(dens),tn=tanh(Bz)
summary(lm(kp ~ .^3, data = table5))
# Out:
# Call:
# lm(formula = kp ~ .^3, data = table5)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.6896 -0.3594 -0.0092  0.2972  3.7068
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  1.595e+01  6.482e+01   0.246   0.8060
# v           -1.189e-01  3.627e-01  -0.328   0.7437
# n            1.091e+01  2.887e+01   0.378   0.7063
# bz          -7.833e+00  1.568e+01  -0.499   0.6185
# v2           2.967e-04  6.431e-04   0.461   0.6454
# n2          -3.360e+00  3.964e+00  -0.847   0.3986
# bz2         -5.655e+00  4.240e+00  -1.334   0.1851
# ev           6.277e+00  1.513e+01   0.415   0.6790
# v:n         -5.301e-02  1.598e-01  -0.332   0.7408
# v:bz         2.821e-02  7.034e-02   0.401   0.6892
# v:v2        -2.184e-07  3.666e-07  -0.596   0.5526
# v:n2         1.569e-02  2.081e-02   0.754   0.4524
# v:bz2        2.555e-02  1.707e-02   1.497   0.1373
# v:ev        -2.777e-02  5.992e-02  -0.463   0.6440
# ...

# %%
table6 <- data.frame(kp=Kp,v=velo,n=dens,bz=Bz,v2=velo**2,n2=dens**2,bz2=Bz**2,ebz=exp(Bz),sbz=sinh(Bz))
#,tn=tanh(dens),tn=tanh(Bz)
summary(lm(kp ~ .^4, data = table6))
# Out:
# Call:
# lm(formula = kp ~ .^4, data = table6)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.60244 -0.11217 -0.00002  0.09838  1.87816
#
# Coefficients: (18 not defined because of singularities)
#                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)    -1.293e+04  2.779e+04  -0.465    0.646
# v               1.195e+02  1.364e+02   0.876    0.389
# n              -1.203e+02  3.555e+03  -0.034    0.973
# bz             -1.330e+04  2.767e+04  -0.481    0.635
# v2             -2.239e-01  2.610e-01  -0.858    0.399
# n2             -1.872e+02  3.893e+02  -0.481    0.635
# bz2            -3.762e+03  5.181e+03  -0.726    0.474
# ebz             1.335e+04  2.790e+04   0.479    0.636
# sbz             2.256e+03  1.664e+04   0.136    0.893
# v:n            -3.611e+00  7.616e+00  -0.474    0.639
# v:bz            1.402e+02  1.283e+02   1.093    0.284
# v:v2            1.412e-04  1.704e-04   0.829    0.415
# ...

# %%
table7 <- data.frame(kp=Kp,v=velo,bz=Bz,n2=dens**2,lnv=log(velo),lndens=log(dens),v1=1/velo,d1=1/dens,ebz=exp(Bz))
#,tn=tanh(dens),tn=tanh(Bz)
table7.glm=glm(kp ~ .^3, data = table7)
step(table7.glm,direction="backward")
# Out:
# Start:  AIC=504.18
# kp ~ (v + bz + n2 + lnv + lndens + v1 + d1 + ebz)^3
#
#
# Step:  AIC=504.18
# kp ~ v + bz + n2 + lnv + lndens + v1 + d1 + ebz + v:bz + v:n2 +
#     v:lnv + v:lndens + v:v1 + v:d1 + v:ebz + bz:n2 + bz:lnv +
#     bz:lndens + bz:v1 + bz:d1 + bz:ebz + n2:lnv + n2:lndens +
#     n2:v1 + n2:d1 + n2:ebz + lnv:lndens + lnv:v1 + lnv:d1 + lnv:ebz +
#     lndens:v1 + lndens:d1 + lndens:ebz + v1:d1 + v1:ebz + d1:ebz +
#     v:bz:n2 + v:bz:lnv + v:bz:lndens + v:bz:v1 + v:bz:d1 + v:bz:ebz +
#     v:n2:lnv + v:n2:lndens + v:n2:v1 + v:n2:d1 + v:n2:ebz + v:lnv:lndens +
#     v:lnv:v1 + v:lnv:d1 + v:lnv:ebz + v:lndens:v1 + v:lndens:d1 +
#     v:lndens:ebz + v:v1:d1 + v:d1:ebz + bz:n2:lnv + bz:n2:lndens +
#     bz:n2:v1 + bz:n2:d1 + bz:n2:ebz + bz:lnv:lndens + bz:lnv:v1 +
#     bz:lnv:d1 + bz:lnv:ebz + bz:lndens:v1 + bz:lndens:d1 + bz:lndens:ebz +
#     bz:v1:d1 + bz:v1:ebz + bz:d1:ebz + n2:lnv:lndens + n2:lnv:v1 +
# ...

# %%
summary(lm(kp ~ v + bz + n2 + lnv + lndens + v1 + d1 + ebz + 
    v:bz + v:n2 + v:lnv + v:lndens + v:d1 + v:ebz + bz:n2 + bz:lnv + 
    bz:lndens + bz:v1 + bz:d1 + bz:ebz + n2:lnv + n2:lndens + 
    n2:v1 + n2:d1 + n2:ebz + lnv:lndens + lnv:v1 + lnv:d1 + lnv:ebz + 
    lndens:v1 + lndens:d1 + lndens:ebz + v1:d1 + v1:ebz + d1:ebz + 
    v:bz:lnv + v:bz:lndens + v:bz:d1 + v:n2:lnv + v:n2:d1 + v:lnv:d1 + 
    v:lndens:d1 + v:lndens:ebz + v:d1:ebz + bz:n2:lnv + bz:n2:lndens + 
    bz:n2:v1 + bz:n2:d1 + bz:n2:ebz + bz:lnv:lndens + bz:lnv:v1 + 
    bz:lnv:d1 + bz:lndens:v1 + bz:lndens:d1 + bz:lndens:ebz + 
    bz:v1:d1 + bz:d1:ebz + n2:lnv:lndens + n2:lnv:v1 + n2:lnv:d1 + 
    n2:lndens:v1 + n2:lndens:ebz + n2:v1:d1 + n2:d1:ebz + lnv:lndens:v1 + 
    lnv:lndens:d1 + lnv:lndens:ebz + lnv:v1:d1 + lnv:v1:ebz + 
    lnv:d1:ebz + lndens:v1:d1 + lndens:v1:ebz + lndens:d1:ebz + 
    v1:d1:ebz, data = table7))
# Out:
# Call:
# lm(formula = kp ~ v + bz + n2 + lnv + lndens + v1 + d1 + ebz +
#     v:bz + v:n2 + v:lnv + v:lndens + v:d1 + v:ebz + bz:n2 + bz:lnv +
#     bz:lndens + bz:v1 + bz:d1 + bz:ebz + n2:lnv + n2:lndens +
#     n2:v1 + n2:d1 + n2:ebz + lnv:lndens + lnv:v1 + lnv:d1 + lnv:ebz +
#     lndens:v1 + lndens:d1 + lndens:ebz + v1:d1 + v1:ebz + d1:ebz +
#     v:bz:lnv + v:bz:lndens + v:bz:d1 + v:n2:lnv + v:n2:d1 + v:lnv:d1 +
#     v:lndens:d1 + v:lndens:ebz + v:d1:ebz + bz:n2:lnv + bz:n2:lndens +
#     bz:n2:v1 + bz:n2:d1 + bz:n2:ebz + bz:lnv:lndens + bz:lnv:v1 +
#     bz:lnv:d1 + bz:lndens:v1 + bz:lndens:d1 + bz:lndens:ebz +
#     bz:v1:d1 + bz:d1:ebz + n2:lnv:lndens + n2:lnv:v1 + n2:lnv:d1 +
#     n2:lndens:v1 + n2:lndens:ebz + n2:v1:d1 + n2:d1:ebz + lnv:lndens:v1 +
#     lnv:lndens:d1 + lnv:lndens:ebz + lnv:v1:d1 + lnv:v1:ebz +
#     lnv:d1:ebz + lndens:v1:d1 + lndens:v1:ebz + lndens:d1:ebz +
#     v1:d1:ebz, data = table7)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# ...

# %%
table7 <- data.frame(kp=Kp,v=velo,n=dens,bz=Bz,I=I(Bz**3))
#,tn=tanh(dens),tn=tanh(Bz)
summary(lm(kp ~ .^4, data = table7))
# Out:
# Call:
# lm(formula = kp ~ .^4, data = table7)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.4318 -0.5660 -0.0194  0.5522  3.7946
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -2.619e+00  7.582e-01  -3.454 0.000713 ***
# v            8.539e-03  1.478e-03   5.777 4.05e-08 ***
# n            1.759e-02  1.376e-01   0.128 0.898405
# bz          -4.199e-01  3.820e-01  -1.099 0.273342
# I           -2.004e-03  1.263e-02  -0.159 0.874144
# v:n          4.106e-04  2.970e-04   1.382 0.168871
# v:bz        -1.577e-04  7.739e-04  -0.204 0.838827
# v:I          1.373e-05  2.856e-05   0.481 0.631365
# n:bz         7.655e-03  6.795e-02   0.113 0.910455
# n:I          4.775e-04  2.326e-03   0.205 0.837583
# bz:I         1.333e-03  1.110e-03   1.200 0.231807
# v:n:bz       7.353e-05  1.514e-04   0.486 0.627902
# v:n:I       -2.759e-06  5.762e-06  -0.479 0.632715
# v:bz:I      -1.091e-06  2.668e-06  -0.409 0.683189
# ...

# %%
table7 <- data.frame(kp=Kp,v=velo**(4/3),n=(dens**(1/2)),bz=Bz**(2/3),v=velo**(2))
#,tn=tanh(dens),tn=tanh(Bz)
summary(lm(kp ~ .^3, data = table7))
# Out:
# Call:
# lm(formula = kp ~ .^3, data = table7)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -2.47353 -0.58657  0.03733  0.61294  2.85634
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -1.968e+00  5.769e+01  -0.034    0.973
# v            2.674e-03  6.749e-02   0.040    0.969
# n            8.064e+00  2.055e+01   0.392    0.696
# bz          -7.575e+00  2.101e+01  -0.361    0.720
# v.1         -7.123e-05  1.021e-03  -0.070    0.945
# v:n         -9.886e-03  2.423e-02  -0.408    0.685
# v:bz         9.473e-03  2.325e-02   0.407    0.685
# v:v.1        7.719e-09  4.612e-08   0.167    0.868
# n:bz         2.076e-01  4.391e+00   0.047    0.962
# n:v.1        1.696e-04  3.706e-04   0.458    0.649
# bz:v.1      -1.403e-04  3.362e-04  -0.417    0.678
# v:n:bz      -5.344e-04  3.591e-03  -0.149    0.882
# v:n:v.1     -9.432e-09  1.735e-08  -0.544    0.588
# v:bz:v.1     5.558e-09  1.361e-08   0.409    0.684
# ...

# %%
table8 <- data.frame(kp=Kp,v=velo,n,bz=Bz,n2=dens**2,lnv=log(velo),en=exp(dens),lnn=log(dens))
#,tn=tanh(dens),tn=tanh(Bz)
table8.glm=glm(kp ~ .^2, data = table8)
step(table8.glm,direction="backward")
# Out:
# Start:  AIC=478.95
# kp ~ (v + n + bz + n2 + lnv + en + lnn)^2
#
#           Df Deviance    AIC
# - v:n      1   116.03 476.96
# - n2:lnv   1   116.04 476.98
# - v:lnn    1   116.07 477.02
# - n:lnv    1   116.08 477.04
# - v:n2     1   116.13 477.10
# - lnv:lnn  1   116.16 477.15
# - bz:en    1   116.34 477.42
# - n:lnn    1   116.40 477.51
# - bz:n2    1   116.46 477.60
# - lnv:en   1   116.72 477.98
# - n2:lnn   1   116.76 478.03
# - n:bz     1   116.94 478.29
# - v:en     1   117.04 478.44
# - n:n2     1   117.22 478.71
# - bz:lnn   1   117.28 478.79
# <none>         116.03 478.95
# - en:lnn   1   118.96 481.22
# - n:en     1   118.97 481.25
# - n2:en    1   118.97 481.25
# - v:lnv    1   119.01 481.30
# - bz:lnv   1   122.20 485.82
# - v:bz     1   122.40 486.10
#
# Step:  AIC=476.96
# kp ~ v + n + bz + n2 + lnv + en + lnn + v:bz + v:n2 + v:lnv +
#     v:en + v:lnn + n:bz + n:n2 + n:lnv + n:en + n:lnn + bz:n2 +
#     bz:lnv + bz:en + bz:lnn + n2:lnv + n2:en + n2:lnn + lnv:en +
# ...

# %%
summary(lm(kp ~  v + n + bz + n2 + lnv + en + lnn + v:bz + 
    v:n2 + v:lnv + v:en + n:bz + n:n2 + n:lnv + n:en + bz:n2 + 
    bz:lnv + bz:lnn + n2:en + n2:lnn + lnv:lnn + en:lnn, data = table8))
# Out:
# Call:
# lm(formula = kp ~ v + n + bz + n2 + lnv + en + lnn + v:bz + v:n2 +
#     v:lnv + v:en + n:bz + n:n2 + n:lnv + n:en + bz:n2 + bz:lnv +
#     bz:lnn + n2:en + n2:lnn + lnv:lnn + en:lnn, data = table8)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.1791 -0.5336 -0.0100  0.4690  3.6033
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  2.680e+02  1.749e+02   1.532  0.12763
# v            1.076e+00  5.978e-01   1.800  0.07392 .
# n            6.663e+01  3.706e+01   1.798  0.07422 .
# bz           1.125e+01  4.408e+00   2.552  0.01172 *
# n2          -3.723e+01  1.403e+01  -2.653  0.00885 **
# lnv         -7.570e+01  4.059e+01  -1.865  0.06414 .
# en           2.633e-01  9.739e-02   2.704  0.00766 **
# lnn          1.582e+01  2.885e+01   0.548  0.58428
# v:bz         4.584e-03  1.685e-03   2.721  0.00728 **
# v:n2        -6.632e-04  3.166e-04  -2.095  0.03792 *
# v:lnv       -1.275e-01  7.185e-02  -1.774  0.07806 .
# ...

# %%
kp=Kp;
v=velo;
n=dens;
bz=Bz;
n2=dens**2;
lnv=log(velo);
en=exp(dens)
G=(2.596e+02)+ v*(8.406e-01)+ n*(-1.282e+01)+ bz*(1.068e+0)+ n2*(-1.044e-02)+lnv*(-6.009e+00)+(-5.216e-03)*v*n
+ (4.135e-03)*v*bz+v*lnv*(-9.822e-02)+(2.542e+00)*n*lnv+(8.785e-04)*bz*n2-(2.105e+00)*bz*lnv-Kp

 Les erreurs des  points de test sont differents ou non?
# Out:
#   [1] -213.723562    3.237737 -106.302120  -74.015539 -120.868653 -141.306183
#   [7]   12.644702   45.607851 -161.227791 -192.532635 -185.093633  -38.576899
#  [13] -259.176940 -128.632760  -88.804155  -66.915590 -243.086161 -239.503740
#  [19] -257.368015 -147.194673 -478.491324 -200.773437  -89.698777 -184.244925
#  [25]  -47.546208  -31.198067 -258.847949 -188.180947 -171.569400 -212.853346
#  [31] -196.488643  -96.331765  -87.465999 -105.178981 -322.931116 -189.345408
#  [37] -110.559903  -73.213087 -121.718490 -186.464152 -161.368188  -40.419267
#  [43] -218.573479 -109.504938 -164.038959 -214.491227 -214.214809 -312.846981
#  [49] -205.577720  -89.958273  -16.678912 -106.915935  -50.386895  -46.502824
#  [55] -115.321302 -141.063677 -235.981621 -333.832589  -36.482038 -188.242507
#  [61]  -26.896706 -272.719167 -170.011326 -205.845426 -250.432230 -212.269914
#  [67] -169.931090  -87.642619 -385.258174 -261.921555 -217.323326 -165.232219
# ...
